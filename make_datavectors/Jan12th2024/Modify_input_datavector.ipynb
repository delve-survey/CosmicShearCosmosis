# %%
import numpy as np
import matplotlib.pyplot as pl
from astropy.io import fits
# %matplotlib inline

# %%
f=fits.open('/project/chihway/dhayaa/DECADE/cosmosis/Lucas_files/simulated_shear_Oct17th.fits')
f.info()
# Out:
# Filename: /project/chihway/dhayaa/DECADE/cosmosis/Lucas_files/simulated_shear_Oct17th.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  COVMAT        1 ImageHDU        13   (400, 400)   float64
#   2  xip           1 BinTableHDU     35   200R x 7C   [K, K, K, D, D, D, D]
#   3  xim           1 BinTableHDU     35   200R x 7C   [K, K, K, D, D, D, D]
#   4  nz_source     1 BinTableHDU     24   81R x 7C   [D, D, D, D, D, D, D]

# %%
b = fits.open('/project/chihway/nchicoine/baryonic/simulated_shear_delve.fits')
b.info()
# Out:
# Filename: /project/chihway/nchicoine/baryonic/simulated_shear_delve.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  COVMAT        1 ImageHDU        13   (400, 400)   float64
#   2  xip           1 BinTableHDU     35   200R x 7C   [K, K, K, D, D, D, D]
#   3  xim           1 BinTableHDU     35   200R x 7C   [K, K, K, D, D, D, D]
#   4  nz_source     1 BinTableHDU     24   81R x 7C   [D, D, D, D, D, D, D]

# %%
b['xim'].data
# Out:
# FITS_rec([(1, 1,  0, 1.42207546e-06,   2.5       ,   3.14731353,   2.83602296),
#           (1, 1,  1, 1.45273762e-06,   3.14731353,   3.96223298,   3.57034138),
#           (1, 1,  2, 1.47433842e-06,   3.96223298,   4.98815579,   4.49479349),
#           (1, 1,  3, 1.48194934e-06,   4.98815579,   6.27971608,   5.65860974),
#           (1, 1,  4, 1.47003781e-06,   6.27971608,   7.90569415,   7.1237676 ),
#           (1, 1,  5, 1.43099553e-06,   7.90569415,   9.95267926,   8.96829206),
#           (1, 1,  6, 1.36222266e-06,   9.95267926,  12.52968084,  11.29041078),
#           (1, 1,  7, 1.26551446e-06,  12.52968084,  15.77393361,  14.21378504),
#           (1, 1,  8, 1.14722404e-06,  15.77393361,  19.85820587,  17.89409518),
#           (1, 1,  9, 1.01555820e-06,  19.85820587,  25.        ,  22.52733114),
#           (1, 1, 10, 8.79156577e-07,  25.        ,  31.47313529,  28.36022963),
#           (1, 1, 11, 7.46960560e-07,  31.47313529,  39.62232981,  35.70341377),
# ...

# %%
f['xim'].data
# Out:
# FITS_rec([(1, 1,  0, 1.95448861e-06,   2.5       ,   3.14731353,   2.83602296),
#           (1, 1,  1, 1.98642008e-06,   3.14731353,   3.96223298,   3.57034138),
#           (1, 1,  2, 1.99122912e-06,   3.96223298,   4.98815579,   4.49479349),
#           (1, 1,  3, 1.96400315e-06,   4.98815579,   6.27971608,   5.65860974),
#           (1, 1,  4, 1.90119108e-06,   6.27971608,   7.90569415,   7.1237676 ),
#           (1, 1,  5, 1.80213097e-06,   7.90569415,   9.95267926,   8.96829206),
#           (1, 1,  6, 1.66987919e-06,   9.95267926,  12.52968084,  11.29041078),
#           (1, 1,  7, 1.51114681e-06,  12.52968084,  15.77393361,  14.21378504),
#           (1, 1,  8, 1.33554112e-06,  15.77393361,  19.85820587,  17.89409518),
#           (1, 1,  9, 1.15408397e-06,  19.85820587,  25.        ,  22.52733114),
#           (1, 1, 10, 9.77417128e-07,  25.        ,  31.47313529,  28.36022963),
#           (1, 1, 11, 8.14238268e-07,  31.47313529,  39.62232981,  35.70341377),
# ...

# %%
Mask = (b['xip'].data['BIN1'] == 1) & (b['xip'].data['BIN2'] == 2)
pl.plot(b['xim'].data['ANGBIN'][Mask], f['xim'].data['VALUE'][Mask],  label = 'Original')
pl.plot(b['xim'].data['ANGBIN'][Mask], b['xim'].data['VALUE'][Mask],  label = 'Baryonified')
pl.xlabel('bin_num')
pl.legend()

# %%
b['nz_source'].data
# Out:
# FITS_rec([(-0.015625, 0.      , 0.015625, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00),
#           ( 0.      , 0.015625, 0.03125 , 9.20183861e-02, 2.15984268e-02, 8.38541827e-03, 2.41938997e-03),
#           ( 0.03125 , 0.046875, 0.0625  , 2.38284436e-01, 6.87900030e-02, 2.65262490e-02, 7.01327086e-03),
#           ( 0.0625  , 0.078125, 0.09375 , 5.15499047e-01, 1.48770610e-01, 6.06566096e-02, 1.50788015e-02),
#           ( 0.09375 , 0.109375, 0.125   , 9.46207963e-01, 2.60306685e-01, 1.11888763e-01, 2.73103141e-02),
#           ( 0.125   , 0.140625, 0.15625 , 2.18565665e+00, 6.05196070e-01, 2.34189495e-01, 5.74060158e-02),
#           ( 0.15625 , 0.171875, 0.1875  , 2.46193219e+00, 7.60568675e-01, 2.57886245e-01, 6.23793585e-02),
#           ( 0.1875  , 0.203125, 0.21875 , 2.82620897e+00, 1.08234278e+00, 3.57274185e-01, 8.37017489e-02),
#           ( 0.21875 , 0.234375, 0.25    , 2.70099799e+00, 1.31738829e+00, 4.53775712e-01, 1.05863787e-01),
# ...

# %%
f['nz_source'].data
# Out:
# FITS_rec([(-0.015625, 0.      , 0.015625, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00),
#           ( 0.      , 0.015625, 0.03125 , 9.20183861e-02, 2.15984268e-02, 8.38541827e-03, 2.41938997e-03),
#           ( 0.03125 , 0.046875, 0.0625  , 2.38284436e-01, 6.87900030e-02, 2.65262490e-02, 7.01327086e-03),
#           ( 0.0625  , 0.078125, 0.09375 , 5.15499047e-01, 1.48770610e-01, 6.06566096e-02, 1.50788015e-02),
#           ( 0.09375 , 0.109375, 0.125   , 9.46207963e-01, 2.60306685e-01, 1.11888763e-01, 2.73103141e-02),
#           ( 0.125   , 0.140625, 0.15625 , 2.18565665e+00, 6.05196070e-01, 2.34189495e-01, 5.74060158e-02),
#           ( 0.15625 , 0.171875, 0.1875  , 2.46193219e+00, 7.60568675e-01, 2.57886245e-01, 6.23793585e-02),
#           ( 0.1875  , 0.203125, 0.21875 , 2.82620897e+00, 1.08234278e+00, 3.57274185e-01, 8.37017489e-02),
#           ( 0.21875 , 0.234375, 0.25    , 2.70099799e+00, 1.31738829e+00, 4.53775712e-01, 1.05863787e-01),
# ...
